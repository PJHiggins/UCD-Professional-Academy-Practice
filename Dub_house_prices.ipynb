# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import requests as rsts
import json

# %%
url = 'https://ws.cso.ie/public/api.jsonrpc?data=%7B%22jsonrpc%22:%222.0%22,%22method%22:%22PxStat.Data.Cube_API.ReadDataset%22,%22params%22:%7B%22class%22:%22query%22,%22id%22:%5B%22TLIST(A1)%22%5D,%22dimension%22:%7B%22TLIST(A1)%22:%7B%22category%22:%7B%22index%22:%5B%222022%22%5D%7D%7D%7D,%22extension%22:%7B%22pivot%22:%22TLIST(A1)%22,%22codes%22:false,%22language%22:%7B%22code%22:%22en%22%7D,%22format%22:%7B%22type%22:%22JSON-stat%22,%22version%22:%222.0%22%7D,%22matrix%22:%22HPA04%22%7D,%22version%22:%222.0%22%7D%7D'

# %%
dub_houses = rsts.get (url).json()

# %%
print (dub_houses)
# Out:
# {'jsonrpc': '2.0', 'result': {'class': 'dataset', 'dimension': {'STATISTIC': {'category': {'index': ['HPA04C01', 'HPA04C02', 'HPA04C03', 'HPA04C04'], 'label': {'HPA04C01': 'Volume of Sales', 'HPA04C02': 'Value of Sales', 'HPA04C03': 'Mean Sale Price', 'HPA04C04': 'Median Price'}, 'unit': {'HPA04C01': {'decimals': 0, 'label': 'Number', 'position': 'end'}, 'HPA04C02': {'decimals': 1, 'label': 'Euro Million', 'position': 'end'}, 'HPA04C03': {'decimals': 0, 'label': 'Euro', 'position': 'end'}, 'HPA04C04': {'decimals': 0, 'label': 'Euro', 'position': 'end'}}}, 'label': 'Statistic'}, 'TLIST(A1)': {'category': {'index': ['2022'], 'label': {'2022': '2022'}}, 'label': 'Year'}, 'C03346V04033': {'category': {'index': ['-', '01', '02'], 'label': {'-': 'All Dwelling Statuses', '01': 'New', '02': 'Existing'}}, 'label': 'Dwelling Status'}, 'C03349V04063': {'category': {'index': ['-', 'A41', 'A42', 'A45', 'A63', 'A67', 'A75', 'A81', 'A82', 'A83', 'A84', 'A85', 'A86', 'A91', 'A92', 'A94', 'A96', 'A98
# ...

# %%
pd.DataFrame(dub_houses['label']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26812\2000908781.py in <module>
# ----> 1 pd.DataFrame(dub_houses['label']).head()
#
# KeyError: 'label'
