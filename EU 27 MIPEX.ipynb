# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
from bs4 import BeautifulSoup

# %%
#EU_27= 'Belgium', 'Bulgaria', 'Czechia', 'Denmark', 'Germany', 'Estonia', 'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy', 'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta', 'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania', 'Slovenia', 'Slovakia', 'Finland', 'Sweden'

# %%
#MIPEX acronyms

# %%
#Sheet names EU 27 : 'BE', 'BG', 'CZ', 'DK', 'DE', 'EE', 'IE', 'GR', 'ES', 'FR', 'HR', 'IT', 'CY', 'LV','LT','LU', 'HU',  'MT', 'NL', 'AT', 'PL', 'PT', 'RO', 'SI', 'SK', 'FI', 'SE'

# %%
acronyms = ['BE', 'BG', 'CZ', 'DK', 'DE', 'EE', 'IE', 'GR', 'ES', 'FR', 'HR', 'IT', 'CY', 'LV','LT','LU', 'HU',  'MT', 'NL', 'AT', 'PL', 'PT', 'RO', 'SI', 'SK', 'FI', 'SE']

# %%
np.count_nonzero(np.array(acronyms))
# Out:
# 27

# %%
file_path = r"C:\Users\higgi\OneDrive\Documents\In progress\data analysis\MIPEX\Policy Indicators Scores (2007-2019) – core set of indicators (3).xlsx"

# %%
#columns = ['Year', 'Overall_Score_w_health', 'Overall_Score_w/o_health', 'Overall_Score_w/o_health_and_education']

# %%
dict_df = pd.read_excel (file_path, sheet_name = acronyms, skiprows = 1, nrows = 14, usecols = [0,1,2,3])

# %%
print (dict_df)
# Out:
# {'BE':       Year  Overall Score (with health)  Overall Score (with/out health)  \
# 0   2007.0                          NaN                              NaN
# 1   2008.0                          NaN                              NaN
# 2   2009.0                          NaN                        73.963719
# 3   2010.0                          NaN                        74.225624
# 4   2011.0                          NaN                        71.574830
# 5   2012.0                          NaN                        71.574830
# 6   2013.0                          NaN                        69.630385
# 7   2014.0                    68.744296                        69.630385
# 8   2015.0                          NaN                        69.630385
# 9   2016.0                          NaN                        68.836735
# 10  2017.0                          NaN                        68.836735
# 11  2018.0                          NaN                        68.836735
# ...

# %%
dict_df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30520\2039303529.py in <module>
# ----> 1 dict_df.type()
#
# AttributeError: 'dict' object has no attribute 'type'

# %%
df = pd.DataFrame (dict_df, index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30520\1239137015.py in <module>
# ----> 1 df = pd.DataFrame (dict_df, index = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...
